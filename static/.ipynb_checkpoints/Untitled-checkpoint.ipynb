# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('jan_2023.csv')

df_ints = df.drop(columns=['hvfhs_license_num', 'request_datetime', 'PUBorough', 'PUZone', 'DOBorough', 'DOZone'])

fig, ax =  plt.subplots(figsize=(15,15))
sns.heatmap(round(df_ints.corr(),2), annot=True, cmap='PuBuGn')

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('jan_2023.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   DOLocationID          10000 non-null  int64
#  1   PULocationID          10000 non-null  int64
#  2   hvfhs_license_num     10000 non-null  object
#  3   request_datetime      10000 non-null  object
#  4   trip_miles            10000 non-null  float64
#  5   trip_time             10000 non-null  int64
#  6   base_passenger_fare   10000 non-null  float64
#  7   tolls                 10000 non-null  float64
#  8   bcf                   10000 non-null  float64
#  9   sales_tax             10000 non-null  float64
#  10  congestion_surcharge  10000 non-null  float64
#  11  airport_fee           10000 non-null  float64
#  12  tips                  10000 non-null  float64
#  13  driver_pay            10000 non-null  float64
#  14  PUBorough             10000 non-null  object
#  15  PUZone                10000 non-null  object
#  16  DOBorough             9583 non-null   object
#  17  DOZone                10000 non-null  object
# dtypes: float64(9), int64(3), object(6)
# memory usage: 1.4+ MB

# %%
df_ints = df.drop(columns=['hvfhs_license_num', 'request_datetime', 'PUBorough', 'PUZone', 'DOBorough', 'DOZone'])

# %%
fig, ax =  plt.subplots(figsize=(15,15))
sns.heatmap(round(df_ints.corr(),2), annot=True, cmap='PuBuGn')
# Out:
# <Axes: >
